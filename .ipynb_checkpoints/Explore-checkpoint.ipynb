# %%
import fastPAT as fpat
import Load_PAT2D_data as data
import matplotlib
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
path = '/local/scratch/public/sl767/ModelCorrection/'
train_append = 'trainDataSet.mat'
test_append = 'testDataSet.mat'
forward_grid_append = 'kgrid_smallForw.mat'
backward_grid_append = 'kgrid_small.mat'
train_path = path + train_append
test_path = path + test_append
for_grid_path = path + forward_grid_append
back_grid_path = path + backward_grid_append

# %%
### getting the data loading methods in place
data_sets = data.read_data_sets(test_path)
# Out:
# Start loading test data
# (256, 64, 64)
# (256, 64, 64)
# (256, 64, 64)

# %%
dataApr, dataTrue, imageTrue = data_sets.test.next_batch(16)

# %%
### initialize PAT transform - the grids
kgridBack = fpat.kgrid(back_grid_path)
kgridForw = fpat.kgrid(for_grid_path)
# Out:
# (64, 127)
# (64, 127)
# (64, 127)
# (128, 64)
# (128, 64)
# (128, 64)

# %%
pat = fpat.fastPAT(kgridBack, kgridForw, 60)

# %%
sim_data = pat.kspace_forward(imageTrue[0,...])

# %%
plt.figure()
plt.subplot(131)
plt.imshow(sim_data)
plt.subplot(132)
plt.imshow(dataApr[0,...])
plt.subplot(133)
plt.imshow(dataTrue[0,...])
plt.show()
